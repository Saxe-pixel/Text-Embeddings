# %%
from pathlib import Path
import sqlite3
import subprocess
import h5py

BASE = Path.cwd().parent.parent / 'WikiData.nosync'

# %% [markdown]
# ### Query wikidata_labeled_wo.db
#
# Connects to the labeled database and returns the row where the QID is Q42.

# %%
path = BASE / 'wikidata_labeled_wo.db'
with sqlite3.connect(path) as conn:
    cur = conn.cursor()
    cur.execute("SELECT * FROM properties_labeled WHERE qid='Q42';")
    rows = cur.fetchall()
    for row in rows:
        print(row)
# Out:
# ('Q42', 'Douglas Adams', 'about', None, 'Q42', 'Douglas Adams')
# ('Q42', 'Douglas Adams', 'P31', 'instance of', 'Q5', 'human')
# ('Q42', 'Douglas Adams', 'P21', 'sex or gender', 'Q6581097', 'male')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q214917', 'playwright')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q28389', 'screenwriter')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q6625963', 'novelist')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q4853732', "children's writer")
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q18844224', 'science fiction writer')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q245068', 'comedian')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q36180', 'writer')
# ('Q42', 'Douglas Adams', 'P106', 'occupation', 'Q639669', 'musician')
# ('Q42', 'Douglas Adams', 'P800', 'notable work', 'Q25169', "The Hitchhiker's Guide to the Galaxy pentalogy")
# ('Q42', 'Douglas Adams', 'P800', 'notable work', 'Q20736364', 'Dirk Gently series')
# ('Q42', 'Douglas Adams', 'P800', 'notable work', 'Q7758404', 'The Private Life of Genghis Khan')
# ('Q42', 'Douglas Adams', 'P569', 'date of birth', '1952-03-11', None)
# ('Q42', 'Douglas Adams', 'P19', 'place of birth', 'Q350', 'Cambridge')
# ('Q42', 'Douglas Adams', 'P570', 'date of death', '2001-05-11', None)
# ('Q42', 'Douglas Adams', 'P1196', 'manner of death', 'Q3739104', 'natural causes')
# ('Q42', 'Douglas Adams', 'P509', 'cause of death', 'Q12152', 'myocardial infarction')
# ('Q42', 'Douglas Adams', 'P20', 'place of death', 'Q159288', 'Santa Barbara')
# ('Q42', 'Douglas Adams', 'P119', 'place of burial', 'Q533697', 'Highgate Cemetery')
# ('Q42', 'Douglas Adams', 'P735', 'given name', 'Q463035', 'Douglas')
# ('Q42', 'Douglas Adams', 'P735', 'given name', 'Q19688263', 'Noël')
# ('Q42', 'Douglas Adams', 'P734', 'family name', 'Q351735', 'Adams')
# ('Q42', 'Douglas Adams', 'P27', 'country of citizenship', 'Q145', 'United Kingdom')
# ('Q42', 'Douglas Adams', 'P551', 'residence', 'Q159288', 'Santa Barbara')
# ('Q42', 'Douglas Adams', 'P551', 'residence', 'Q84', 'London')
# ('Q42', 'Douglas Adams', 'P551', 'residence', 'Q909993', 'Brentwood')
# ('Q42', 'Douglas Adams', 'P551', 'residence', 'Q350', 'Cambridge')
# ('Q42', 'Douglas Adams', 'P103', 'native language', 'Q1860', 'English')
# ('Q42', 'Douglas Adams', 'P22', 'father', 'Q14623675', 'Christopher Douglas Adams')
# ('Q42', 'Douglas Adams', 'P25', 'mother', 'Q14623678', 'Janet Adams')
# ('Q42', 'Douglas Adams', 'P40', 'child', 'Q14623683', 'Polly Adams')
# ('Q42', 'Douglas Adams', 'P108', 'employer', 'Q9531', 'BBC')
# ('Q42', 'Douglas Adams', 'P108', 'employer', 'Q3520623', 'The Digital Village')
# ('Q42', 'Douglas Adams', 'P1411', 'nominated for', 'Q3414212', 'Hugo Award for Best Dramatic Presentation')
# ('Q42', 'Douglas Adams', 'P1411', 'nominated for', 'Q2576795', 'Locus Award for Best Science Fiction Novel')
# ('Q42', 'Douglas Adams', 'P910', "topic's main category", 'Q8935487', 'Category:Douglas Adams')
# ('Q42', 'Douglas Adams', 'P1303', 'instrument', 'Q6607', 'guitar')
# ('Q42', 'Douglas Adams', 'P3373', 'sibling', 'Q14623673', 'Susan Adams')
# ('Q42', 'Douglas Adams', 'P136', 'genre', 'Q24925', 'science fiction')
# ('Q42', 'Douglas Adams', 'P136', 'genre', 'Q40831', 'comedy')
# ('Q42', 'Douglas Adams', 'P136', 'genre', 'Q128758', 'satire')
# ('Q42', 'Douglas Adams', 'P26', 'spouse', 'Q14623681', 'Jane Belson')
# ('Q42', 'Douglas Adams', 'P463', 'member of', 'Q857679', 'Footlights')
# ('Q42', 'Douglas Adams', 'P463', 'member of', 'Q5610831', 'Groucho Club')
# ('Q42', 'Douglas Adams', 'P1412', 'languages spoken, written or signed', 'Q1860', 'English')
# ('Q42', 'Douglas Adams', 'P485', 'archives at', 'Q67074906', "St John's College Library")
# ('Q42', 'Douglas Adams', 'P1343', 'described by source', 'Q67311526', 'Obálky knih')
# ('Q42', 'Douglas Adams', 'P6886', 'writing language', 'Q1860', 'English')
# ('Q42', 'Douglas Adams', 'P1424', "topic's main template", 'Q22898962', 'Template:Douglas Adams')
# ('Q42', 'Douglas Adams', 'P7763', 'copyright status as a creator', 'Q73555012', 'works protected by copyrights')
# ('Q42', 'Douglas Adams', 'P1889', 'different from', 'Q21454969', 'Douglas Adams')
# ('Q42', 'Douglas Adams', 'P172', 'ethnic group', 'Q7994501', 'White British')
# ('Q42', 'Douglas Adams', 'P937', 'work location', 'Q84', 'London')
# ('Q42', 'Douglas Adams', 'P1340', 'eye color', 'Q17122705', 'brown')
# ('Q42', 'Douglas Adams', 'P101', 'field of work', 'Q3238422', 'science fiction literature')
# ('Q42', 'Douglas Adams', 'P1813', 'short name', 'Douglas Adams', None)
# ('Q42', 'Douglas Adams', 'P166', 'award received', 'Q2687578', 'Inkpot Award')
# ('Q42', 'Douglas Adams', 'P166', 'award received', 'Q906455', 'Ditmar Award')
# ('Q42', 'Douglas Adams', 'P7084', 'related category', 'Q8722666', 'Category:Films with screenplays by Douglas Adams')
# ('Q42', 'Douglas Adams', 'P1477', 'birth name', 'Douglas No\\u00EBl Adams', None)
# ('Q42', 'Douglas Adams', 'P1559', 'name in native language', 'Douglas Adams', None)
# ('Q42', 'Douglas Adams', 'P5008', 'on focus list of Wikimedia project', 'Q6173448', 'Wikipedia:Vital articles/Level/4')
# ('Q42', 'Douglas Adams', 'P140', 'religion or worldview', 'Q7066', 'atheism')
# ('Q42', 'Douglas Adams', 'P69', 'educated at', 'Q4961791', 'Brentwood School')
# ('Q42', 'Douglas Adams', 'P69', 'educated at', 'Q691283', "St John's College")
# ('Q42', 'Douglas Adams', 'P2031', 'work period (start)', '1974-01-01', None)
# ('Q42', 'Douglas Adams', 'description', None, 'English science fiction writer and humorist (1952–2001)', None)

# %% [markdown]
# ### Query qid_texts_wo_clean.db
#
# Looks up the entry for Q42 in the cleaned text database.

# %%
path = BASE / 'qid_texts_wo_m_clean.db'
with sqlite3.connect(path) as conn:
    cur = conn.cursor()
    # only grab the fields you need
    cur.execute("SELECT qid, text FROM texts WHERE qid = ?;", ('Q42',))
    rows = cur.fetchall()

    for qid, raw_text in rows:
        # if your DB actually stores the two‐character sequence '\'+'n', 
        # turn those into real newlines:
        text = raw_text.replace('\\n', '\n')

        print(f"--- QID: {qid} ---\n")
        # now split on real newlines and print each line
        for line in text.split('\n'):
            print(line)
        print("\n")   # spacer between records
# Out:
# --- QID: Q42 ---
#
# Douglas Adams
# English science fiction writer and humorist (1952–2001)
# Attributes include:
# about: Douglas Adams
# instance of: human
# sex or gender: male
# occupation: playwright, screenwriter, novelist, children's writer, science fiction writer, comedian, writer, musician
# notable work: The Hitchhiker's Guide to the Galaxy pentalogy, Dirk Gently series, The Private Life of Genghis Khan
# date of birth: 1952-03-11
# place of birth: Cambridge
# date of death: 2001-05-11
# manner of death: natural causes
# cause of death: myocardial infarction
# place of death: Santa Barbara
# place of burial: Highgate Cemetery
# given name: Douglas, Noël
# family name: Adams
# country of citizenship: United Kingdom
# residence: Santa Barbara, London, Brentwood, Cambridge
# native language: English
# father: Christopher Douglas Adams
# mother: Janet Adams
# child: Polly Adams
# employer: BBC, The Digital Village
# nominated for: Hugo Award for Best Dramatic Presentation, Locus Award for Best Science Fiction Novel
# topic's main category: Category:Douglas Adams
# instrument: guitar
# sibling: Susan Adams
# genre: science fiction, comedy, satire
# spouse: Jane Belson
# member of: Footlights, Groucho Club
# languages spoken, written or signed: English
# archives at: St John's College Library
# described by source: Obálky knih
# writing language: English
# topic's main template: Template:Douglas Adams
# copyright status as a creator: works protected by copyrights
# different from: Douglas Adams
# ethnic group: White British
# work location: London
# eye color: brown
# field of work: science fiction literature
# short name: Douglas Adams
# award received: Inkpot Award, Ditmar Award
# related category: Category:Films with screenplays by Douglas Adams
# birth name: Douglas No\u00EBl Adams
# name in native language: Douglas Adams
# on focus list of Wikimedia project: Wikipedia:Vital articles/Level/4
# religion or worldview: atheism
# educated at: Brentwood School, St John's College
# work period (start): 1974-01-01

# %% [markdown]
# ### Inspect people_embeddings_test.h5
#
# Uses `h5py` to display the first embedding vector and associated metadata.

# %%
path = BASE / 'people_embeddings_death10k.h5'
# Check if the file exists
if not path.exists():
    print(f"File {path} does not exist. Please check the path.")
else:
    with h5py.File(path, "r") as h5:
        nr = 9000
        print(h5.keys())            # should show 'embeddings', 'qids', 'dod', 'dod_year'
        print(h5["qids"][nr], h5["dod"][nr], h5["dod_year"][nr])
# Out:
# <KeysViewHDF5 ['dod', 'dod_year', 'embeddings', 'qids']>
# b'Q100882593' b'1903-09-03' 1903.0

# %%
# Shows part of the embedding for the same n as above
with h5py.File(path, "r") as h5:
        print(h5["embeddings"][nr])
# Out:
# [ 2.3    -2.115   0.682  ...  0.0433 -0.2769  0.0874]

# %%
path = BASE / 'people_embeddings_death10k.h5'
cmds = [
    ['h5dump', '-d', '/embeddings', '-s', '0,0', '-c', '1,1024', str(path)],
    ['h5dump', '-d', '/qids', '-s', '0', '-c', '1', str(path)],
    ['h5dump', '-d', '/dob', '-s', '0', '-c', '1', str(path)],
    ['h5dump', '-d', '/dob_year', '-s', '0', '-c', '1', str(path)]
]
for cmd in cmds:
    result = subprocess.run(cmd, text=True, capture_output=True)
    print(' '.join(cmd))
    print(result.stdout)
# Out:
# h5dump -d /embeddings -s 0,0 -c 1,1024 /Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5
# HDF5 "/Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5" {
# DATASET "/embeddings" {
#    DATATYPE  H5T_IEEE_F16LE
#    DATASPACE  SIMPLE { ( 10000, 1024 ) / ( 10000, 1024 ) }
#    SUBSET {
#       START ( 0, 0 );
#       STRIDE ( 1, 1 );
#       COUNT ( 1, 1024 );
#       BLOCK ( 1, 1 );
#       DATA {
#       (0,0): 1.93164, -1.57812, 0.769043, 1.97559, 0.468506, -0.223999,
#       (0,6): -2.33789, 0.942383, 0.249634, 0.467773, 1.69336, 2.07812,
#       (0,12): -0.906738, -0.687988, -0.821777, -2.45312, -0.880859,
#       (0,17): -0.737305, 1.59766, 0.535156, 0.896484, 1.22949, -0.851074,
#       (0,23): 1.48047, -1.07324, -0.64209, 3.375, -0.776367, -1.39648,
#       (0,29): 0.671875, 1.4209, -0.993164, 1.29297, -0.820801, -0.00688171,
#       (0,35): 1.07031, 1.13477, -0.797852, -2.00195, 0.145874, 1.14258,
#       (0,41): 1.18555, 0.498535, -1.74316, -0.493408, 0.4104, -1.28027,
#       (0,47): -0.487549, -0.481201, -1.10352, 1.51367, -1.03516, 0.279785,
#       (0,53): 0.365723, 1.37012, -0.770996, 0.131836, -0.516602, -0.0486145,
#       (0,59): 0.460449, -1.16016, 0.0583801, -0.570312, -1.21777, 0.0186615,
#       (0,65): 0.755859, 0.170288, -0.0658569, -0.682129, -0.0921631,
#       (0,70): 0.813965, -0.635254, -0.383057, -0.352051, -0.365479,
#       (0,75): -0.787598, 0.927734, 0.695312, 0.0535583, 0.321777, 0.215332,
#       (0,81): 1.10449, -0.507812, -1.10156, 0.0396118, 2.32422, -1.21973,
#       (0,87): 0.127808, -0.198975, 0.0130539, 0.634277, 0.0285034, 1.08008,
#       (0,93): -1.13281, 0.447754, -0.41748, -0.328857, 0.921875, 0.248779,
#       (0,99): 0.234497, -0.057251, 0.938965, -1.75098, -0.0698853, 0.60498,
#       (0,105): 0.0225677, 1.25781, -1.02637, -0.833496, 1.60938, 0.210815,
#       (0,111): -0.62793, -0.0508118, 0.0587769, 1.08008, 0.0859375, 0.774414,
#       (0,117): 0.227417, 0.324707, -0.174927, -0.137207, -1.32129, -0.399414,
#       (0,962): 0.321777, 0.218018, 0.16687, -0.929688, 0.140625, -0.365234,
#       (0,968): 0.0305939, 0.101807, -0.0419922, -0.441162, 0.0756226,
#       (0,973): 0.134155, 0.212646, -0.870117, -0.182983, 0.217285, 0.359863,
#       (0,979): 0.803223, -0.226074, 0.135742, 0.131958, 0.309326, 0.14563,
#       (0,985): 0.000217557, 0.0814819, 0.87207, 1.14453, 0.299561, -0.511719,
#       (0,991): 0.00862885, 0.164307, -0.214111, 0.455078, -0.415771,
#       (0,996): 0.770508, -0.00182533, 0.342041, -0.281738, 0.00088644,
#       (0,1001): 0.242188, -0.0670776, -0.0585938, -0.280518, 0.247803,
#       (0,1006): 0.138062, -0.631348, -0.249268, 0.230591, 0.115967, 0.392578,
#       (0,1012): 0.59375, 0.130127, -0.766113, 0.565918, -0.0271149,
#       (0,1017): -0.671875, 0.276855, -0.215088, 0.316895, 0.0438538,
#       (0,1022): -0.399902, 0.125488
#       }
#    }
# }
# }
#
# h5dump -d /qids -s 0 -c 1 /Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5
# HDF5 "/Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5" {
# DATASET "/qids" {
#    DATATYPE  H5T_STRING {
#       STRSIZE 10;
#       STRPAD H5T_STR_NULLPAD;
#       CSET H5T_CSET_ASCII;
#       CTYPE H5T_C_S1;
#    }
#    DATASPACE  SIMPLE { ( 10000 ) / ( 10000 ) }
#    SUBSET {
#       START ( 0 );
#       STRIDE ( 1 );
#       COUNT ( 1 );
#       BLOCK ( 1 );
#       DATA {
#       (0): "Q10000001\000"
#       }
#    }
# }
# }
#
# h5dump -d /dob -s 0 -c 1 /Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5
# HDF5 "/Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5" {
# }
#
# h5dump -d /dob_year -s 0 -c 1 /Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5
# HDF5 "/Users/Saxe/Desktop/GitHub/Text-Embeddings/WikiData.nosync/people_embeddings_death10k.h5" {
# }

# %%
with h5py.File(path, "r") as h5:
    #get first 10 qids
    qids = h5["qids"][:20]
    print("First 20 QIDs: ", qids)
    #get last 10 qids
    qids = h5["qids"][-20:]
    print("Last 20 QIDs: ", qids)
# Out:
# First 20 QIDs:  [b'Q10000001' b'Q1000002' b'Q1000005' b'Q100000832' b'Q100000854'
#  b'Q100000857' b'Q100000889' b'Q10000102' b'Q100001260' b'Q1000023'
#  b'Q1000026' b'Q1000034' b'Q1000044' b'Q1000045' b'Q1000048' b'Q100005'
#  b'Q1000051' b'Q1000070' b'Q1000079' b'Q1000085']
# Last 20 QIDs:  [b'Q100955565' b'Q100955595' b'Q100955790' b'Q100955916' b'Q100955957'
#  b'Q100956' b'Q100956016' b'Q100956057' b'Q100956091' b'Q100956112'
#  b'Q100956209' b'Q100956250' b'Q100956262' b'Q100956279' b'Q100956304'
#  b'Q100956317' b'Q100956358' b'Q100956364' b'Q100956370' b'Q100956391']
